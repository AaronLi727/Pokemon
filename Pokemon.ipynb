# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df = pd.read_csv("PokemonGo.csv")

# %%
df.head(10)
# Out:
#    Pokemon No.        Name Type 1  Type 2  Max CP  Max HP  \
# 0            1   Bulbasaur  Grass  Poison    1079      83
# 1            2     Ivysaur  Grass  Poison    1643     107
# 2            3    Venusaur  Grass  Poison    2598     138
# 3            4  Charmander   Fire     NaN     962      73
# 4            5  Charmeleon   Fire     NaN    1568     103
# 5            6   Charizard   Fire  Flying    2620     135
# 6            7    Squirtle  Water     NaN    1015      81
# 7            8   Wartortle  Water     NaN    1594     105
# 8            9   Blastoise  Water     NaN    2560     137
# 9           10    Caterpie    Bug     NaN     446      83
#
#                                            Image URL
# 0  http://cdn.bulbagarden.net/upload/thumb/2/21/0...
# 1  http://cdn.bulbagarden.net/upload/thumb/7/73/0...
# 2  http://cdn.bulbagarden.net/upload/thumb/a/ae/0...
# 3  http://cdn.bulbagarden.net/upload/thumb/7/73/0...
# 4  http://cdn.bulbagarden.net/upload/thumb/4/4a/0...
# ...

# %%
df = df.drop(["Image URL"],axis=1)

# %%
df.shape
# Out:
# (151, 6)

# %%
df.count()
# Out:
# Pokemon No.    151
# Name           151
# Type 1         151
# Type 2          67
# Max CP         151
# Max HP         151
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Pokemon No.     0
# Name            0
# Type 1          0
# Type 2         84
# Max CP          0
# Max HP          0
# dtype: int64

# %%
dcp=df.sort_values(by=["Max CP"], ascending = False)

# %%
dcp.head(10)
# Out:
#      Pokemon No.       Name    Type 1   Type 2  Max CP  Max HP
# 149          150     Mewtwo   Psychic      NaN    4174     180
# 148          149  Dragonite    Dragon   Flying    3525     156
# 150          151        Mew   Psychic      NaN    3322     170
# 145          146    Moltres      Fire   Flying    3263     154
# 144          145     Zapdos  Electric   Flying    3136     154
# 142          143    Snorlax    Normal      NaN    3135     265
# 58            59   Arcanine      Fire      NaN    3005     154
# 130          131     Lapras     Water      Ice    3002     218
# 143          144   Articuno       Ice   Flying    2999     154
# 102          103  Exeggutor     Grass  Psychic    2976     162

# %%
dhp=df.sort_values(by=["Max HP"],ascending = False)

# %%
dhp.head(10)
# Out:
#      Pokemon No.        Name   Type 1 Type 2  Max CP  Max HP
# 112          113     Chansey   Normal    NaN     679     408
# 142          143     Snorlax   Normal    NaN    3135     265
# 39            40  Wigglytuff   Normal  Fairy    2192     233
# 130          131      Lapras    Water    Ice    3002     218
# 133          134    Vaporeon    Water    NaN    2836     218
# 38            39  Jigglypuff   Normal  Fairy     924     194
# 149          150      Mewtwo  Psychic    NaN    4174     180
# 88            89         Muk   Poison    NaN    2621     178
# 111          112      Rhydon   Ground   Rock    2259     178
# 114          115  Kangaskhan   Normal    NaN    2057     178

# %%
df["Max CP"].describe()
# Out:
# count     151.000000
# mean     1637.291391
# std       755.261726
# min       264.000000
# 25%      1001.500000
# 50%      1594.000000
# 75%      2170.500000
# max      4174.000000
# Name: Max CP, dtype: float64

# %%
df["Max HP"].describe()
# Out:
# count    151.000000
# mean     113.350993
# std       45.297417
# min       27.000000
# 25%       83.000000
# 50%      107.000000
# 75%      138.000000
# max      408.000000
# Name: Max HP, dtype: float64

# %%
df["Relations"] = df["Max CP"]/df["Max HP"]

# %%
grouped = df.groupby(["Name", "Type 1", "Relations"])

# %%
dr=df.sort_values(by=["Relations"],ascending=False)

# %%
dr[["Name","Type 1", "Relations"]].head(10)
# Out:
#           Name    Type 1  Relations
# 149     Mewtwo   Psychic  23.188889
# 135    Flareon      Fire  23.147826
# 90    Cloyster     Water  22.714286
# 148  Dragonite    Dragon  22.596154
# 145    Moltres      Fire  21.188312
# 81    Magneton  Electric  20.802198
# 120    Starmie     Water  20.532710
# 144     Zapdos  Electric  20.363636
# 121   Mr. Mime   Psychic  20.066667
# 140   Kabutops      Rock  20.046729
